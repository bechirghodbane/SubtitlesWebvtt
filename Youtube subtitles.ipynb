# %%
pip install yt-dlp
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.2/172.2 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 21.0 MB/s eta 0:00:00
# ...

# %%
# !yt-dlp https://www.youtube.com/playlist?list=PLhpuT8UNWCyDZsF-ePrHuTW4vP3egLNPe --skip-download --write-auto-sub --sub-lang en -o "%(playlist_index)s - %(title)s.%(ext)s"
# Out:
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLhpuT8UNWCyDZsF-ePrHuTW4vP3egLNPe
# [youtube:tab] PLhpuT8UNWCyDZsF-ePrHuTW4vP3egLNPe: Downloading webpage
# [youtube:tab] PLhpuT8UNWCyDZsF-ePrHuTW4vP3egLNPe: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: Ulaby circuits
# [youtube:tab] PLhpuT8UNWCyDZsF-ePrHuTW4vP3egLNPe page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# [youtube:tab] PLhpuT8UNWCyDZsF-ePrHuTW4vP3egLNPe page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (2/3)...
# [youtube:tab] PLhpuT8UNWCyDZsF-ePrHuTW4vP3egLNPe page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (3/3)...
# [youtube:tab] PLhpuT8UNWCyDZsF-ePrHuTW4vP3egLNPe page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Giving up after 3 retries
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !yt-dlp "https://www.youtube.com/shorts/M4dWnRKNPXw" --skip-download --write-auto-sub --sub-lang ar -o "%(title)s.%(ext)s"
# Out:
# [youtube] Extracting URL: https://www.youtube.com/shorts/M4dWnRKNPXw
# [youtube] M4dWnRKNPXw: Downloading webpage
# [youtube] M4dWnRKNPXw: Downloading tv client config
# [youtube] M4dWnRKNPXw: Downloading player 9a279502-main
# [youtube] M4dWnRKNPXw: Downloading tv player API JSON
# [youtube] M4dWnRKNPXw: Downloading ios player API JSON
# [youtube] M4dWnRKNPXw: Downloading m3u8 information
# [info] M4dWnRKNPXw: Downloading subtitles: ar
# [info] M4dWnRKNPXw: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: 12 trailer FHD part1 1.ar.vtt
# [download] Destination: 12 trailer FHD part1 1.ar.vtt
# [download] 100% of   16.01KiB in 00:00:00 at 795.27KiB/s
